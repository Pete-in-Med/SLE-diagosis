# %%
#SLE diagnosis
#the factors used in the project(doctors could easily change these factors to renew the system)
  #test name
    #list_clinical_domain, list_immunology_domain 
  #test weight 
    #all in the forth step
  #test value
    #upANA_r, ANA_value, list_clinical_result_A, list_immunology_result_B, dic_clinical, dic_immunology, dic_all 

#First step : classify by ANA
import sys
while True :
  #input ANA(antinuclear antibodies) at a titer of ≥1:80 on HEp-2 cells or an equivalent positive test (ever)
  ANA_r = input("Do the patient has his or her ANA value?(y/n)")
  #ensure that the system wouldn't break owing to uppercase and lowercase problems
  upANA_r = ANA_r.upper()
  if upANA_r == "N":
    print("In this case, the patient didn't have enough figures to proof that he or she is a SLE patient")
    sys.exit()
  elif upANA_r =="Y" :
    print("Please read the following descriptions before entering the criteria:")
    print(f"1. Do not count a criterion if there is a more likely explanation than SLE\n2. Criteria need not occur simultaneously.\n3. If the symptom has an obvious cause, that specific symptom could not be taken into account.")
    #start to input data
    ANA_value = input("Please enter the value of ANA at a titer of ≥1:80 on HEp-2 cells:")
    break
  elif upANA_r =="" :
    print("You have accidentally pressed the enter button, please try to fill in the data again.")
  else :
    print('Please check to ensure that the input is "y" or "n", and input the data again')


#input data
#Second step : ask for the condition of the patient
#clinical domains and criteria
list_clinical_domain = ["Fever","Autoimmune hemolysis","Thrombocytopenia","Leukopenia","Seizure","Psychosis","Delirium","Acute cutaneous lupus","Subacute cutaneous OR discoid lupus",
"Oral ulcers","Non-scarring alopecia","Acute pericarditis","Pleural or pericardial effusion","Joint involvement","Renal biopsy Class III or IV lupus nephritis", 
"Renal biopsy Class II or V lupus nephritis"]
list_immunology_domain = ["Anti-cardiolipin antibodies OR Anti-β2GP1 antibodies OR  Lupus anticoagulant","Low C3 AND low C4","Low C3 OR low C4 ","Anti-dsDNA antibody* OR Anti-Smith antibody"]
list_clinical_result_A = []
list_clinical_result_1 = []
list_immunology_result_B = []
list_immunology_result_2 = []


#clinical domain
i = 0
#"ni" stands for no information
print(f"\nThe following is the input process of the clinical data!\nPlease use y/n/ni/b to respectively represent yes/no/no information/back")
while i < len(list_clinical_domain):
  print(list_clinical_domain[i],"?","(y/n/ni/b)")
  r = input()
  #ensure that the system wouldn't break owing to uppercase and lowercase problems
  up_r = r.upper()
  if up_r == "N":
    list_clinical_result_A.append(up_r)
    up_r = 0 
    list_clinical_result_1.append(up_r) # adding the element
    i += 1
  elif up_r =="Y" :
    list_clinical_result_A.append(up_r)
    up_r = 1
    list_clinical_result_1.append(up_r) # adding the element
    i += 1
  elif up_r =="NI" :
    list_clinical_result_A.append(up_r)
    up_r = 0
    list_clinical_result_1.append(up_r) # adding the element
    i += 1
  elif up_r =="B" :
    list_clinical_result_A.pop()
    list_clinical_result_1.pop()
    i -= 1
  elif up_r =="" :
    print("You have accidentally pressed the enter button, please try to fill in the data again.")
  else :
    print('Please check to ensure that the input is "y" / "n" / "ni" / "b", and input the data again')

#proteinuria_value distinguishment
while True :
  try:
    proteinuria_value = float(input("What is the proteinuria of the patient? (mg/24h)"))
  except ValueError:
    print('Please check to ensure that the input is an integer or float, and input the data again')
    continue
  if proteinuria_value > 500:
    list_clinical_result_A.append("Y")
    list_clinical_domain.append("Proteinuria >0.5g/24h")
    break 
  elif proteinuria_value =="":
    print("You have accidentally pressed the enter button, please try to fill in the data again.")
  else:
    list_clinical_result_A.append("N")
    list_clinical_domain.append("Proteinuria >0.5g/24h")
    break


#immunology domain
i = 0
#print an empty space to let the system be easier to read
print(f"\nThe following is the input process of the immunology data!\nPlease use y/n/ni/b to respectively represent yes/no/no information/back")
while i < len(list_immunology_domain):
  print(list_immunology_domain[i],"?","(y/n/ni/b)")
  r = input()
  #ensure that the system wouldn't break owing to uppercase and lowercase problems
  up_r = r.upper()
  if up_r == "N":
    list_immunology_result_B.append(up_r)
    up_r = 0 
    list_immunology_result_2.append(up_r) # adding the element
    i += 1
  elif up_r =="Y" :
    list_immunology_result_B.append(up_r)
    up_r = 1
    list_immunology_result_2.append(up_r) # adding the element
    i += 1
  elif up_r =="NI" :
    list_immunology_result_B.append(up_r)
    up_r = 0
    list_immunology_result_2.append(up_r) # adding the element
    i += 1
  elif up_r =="B" :
    list_immunology_result_B.pop()
    list_immunology_result_2.pop()
    i -= 1
  elif up_r =="" :
    print("You have accidentally pressed the enter button, please try to fill in the data again.")
  else :
    print('Please check to ensure that the input is "y" / "n" / "ni" / "b", and input the data again')

  
#Third step : confirm the data
dic_clinical = dict(zip(list_clinical_domain, list_clinical_result_A))
dic_immunology = dict(zip(list_immunology_domain, list_immunology_result_B))
#print readable dictionary
import pprint
print(f"\nThe following part is about clinical data")
pprint.pprint(dic_clinical)
print("Proteinuria value:",proteinuria_value)
print(f"\nThe following part is about immunology data")
pprint.pprint(dic_immunology)
while True :
  confirm = input("Please confirm whether the result is correct or not(y/n):")
  up_confirm = confirm.upper()
  if up_confirm == "Y":
    break
  elif up_confirm == "N":
    #quit the system and ask the doctor to input the data again
    print("If you enter the wrong input, please stop the system and restart the system again")
    sys.exit()
  elif up_confirm =="" :
    print("You have accidentally pressed the enter button, please try to fill in the data again.")
  else :
    print('Please check to ensure that the input is "y" or "n", and input the data again')
  

#Forth step : dealing with data
#patient result
#using the list_clinical_result_1 to calculate the total score
list_patient_Constitutional = list_clinical_result_1[0:1]
list_patient_Hematologic = list_clinical_result_1[1:4]
list_patient_Neuropsychiatric = list_clinical_result_1[4:7]
list_patient_Mucocutaneous = list_clinical_result_1[7:11]
list_patient_Serosal = list_clinical_result_1[11:13]
list_patient_Musculoskeletal = list_clinical_result_1[13:14]
list_patient_Renal = list_clinical_result_1[14:17]

#using the list_clinical_result_2 to calculate the total score
list_patient_Antiphospholipid_antibodies = list_immunology_result_2[0:1]
list_patient_Complement_proteins = list_immunology_result_2[1:3]
list_patient_SLE_specific_antibodies = list_immunology_result_2[3:4]

#weight
list_weight_Constitutional = [2]
list_weight_Hematologic = [4,4,3]
list_weight_Neuropsychiatric = [5,3,2]
list_weight_Mucocutaneous = [6,4,2,2]
list_weight_Serosal = [6,5]
list_weight_Musculoskeletal = [6]
list_weight_Renal = [10,8,4]
list_weight_Antiphospholipid_antibodies = [2]
list_weight_Complement_proteins = [4,3]
list_weight_SLE_specific_antibodies = [6]

#value
list_patient = [list_patient_Constitutional,list_patient_Hematologic,list_patient_Neuropsychiatric,list_patient_Mucocutaneous,list_patient_Serosal,list_patient_Musculoskeletal,
                list_patient_Renal,list_patient_Antiphospholipid_antibodies,list_patient_Complement_proteins,list_patient_SLE_specific_antibodies]
list_weight = [list_weight_Constitutional,list_weight_Hematologic,list_weight_Neuropsychiatric,list_weight_Mucocutaneous,list_weight_Serosal,list_weight_Musculoskeletal,
               list_weight_Renal,list_weight_Antiphospholipid_antibodies,list_weight_Complement_proteins,list_weight_SLE_specific_antibodies]
list_value = []
for i in range(0,len(list_patient)) :
  value = max([x*y for x,y in zip(list_patient[i],list_weight[i])])
  list_value.append(value)

#sum
sum_up = 0
sum_up = sum(list_value)

#Fifth step : output
#classification
if sum_up >= 10 :
  print("The patient is diagnosed as SLE")
else :
  print("The current test project does not provide sufficient evidence to determine a positive result")

#all No Information columns in the list
print(f"If you need more precise results, you need to complete the patient's data by doing the following tests\nHere are the missing data of the patient in the clinical domain")
for key,value in dic_clinical.items():  
    if value == "NI":
        print(key)
print("Here are the missing data of the patient in the immunology domain")
for key,value in dic_immunology.items():  
    if value == "NI":
        print(key) 

#distinguish the main cause of the disease
list_all_domain = list_clinical_domain + list_immunology_domain
dic_all = dict(zip(list_all_domain,list_value))
max_key = max(dic_all, key=dic_all.get)
for key, value in dic_all.items():
    if max_key == key:
        max_value = value
print(f"\nHere is the main cause of the patient to be diagnosed as an SLE patient")
print(max_key)
print("The score of the main cause accounts for",(max_value/sum_up)*100,"%","of the total points")
print((max_value/sum_up)*100,"%")
# Out:
# Do the patient has his or her ANA value?(y/n)y
# Please read the following descriptions before entering the criteria:
# 1. Do not count a criterion if there is a more likely explanation than SLE
# 2. Criteria need not occur simultaneously.
# 3. If the symptom has an obvious cause, that specific symptom could not be taken into account.
# Please enter the value of ANA at a titer of ≥1:80 on HEp-2 cells:4
#
# The following is the input process of the clinical data!
# Please use y/n/ni/b to respectively represent yes/no/no information/back
# Fever ? (y/n/ni/b)
# y
# Autoimmune hemolysis ? (y/n/ni/b)
# n
# Thrombocytopenia ? (y/n/ni/b)
# ni
# Leukopenia ? (y/n/ni/b)
# y
# Seizure ? (y/n/ni/b)
# n
# Psychosis ? (y/n/ni/b)
# n
# Delirium ? (y/n/ni/b)
# n
# Acute cutaneous lupus ? (y/n/ni/b)
# b
# Delirium ? (y/n/ni/b)
# y
# Acute cutaneous lupus ? (y/n/ni/b)
# n
# Subacute cutaneous OR discoid lupus ? (y/n/ni/b)
# n
# Oral ulcers ? (y/n/ni/b)
# ni
# Non-scarring alopecia ? (y/n/ni/b)
# n
# Acute pericarditis ? (y/n/ni/b)
# n
# Pleural or pericardial effusion ? (y/n/ni/b)
# y
# Joint involvement ? (y/n/ni/b)
# n
# Renal biopsy Class III or IV lupus nephritis ? (y/n/ni/b)
# n
# Renal biopsy Class II or V lupus nephritis ? (y/n/ni/b)
# n
# What is the proteinuria of the patient? (mg/24h)401a
# Please check to ensure that the input is an integer or float, and input the data again
# What is the proteinuria of the patient? (mg/24h)401
#
# The following is the input process of the immunology data!
# Please use y/n/ni/b to respectively represent yes/no/no information/back
# Anti-cardiolipin antibodies OR Anti-β2GP1 antibodies OR  Lupus anticoagulant ? (y/n/ni/b)
# y
# Low C3 AND low C4 ? (y/n/ni/b)
# n
# Low C3 OR low C4  ? (y/n/ni/b)
# n
# Anti-dsDNA antibody* OR Anti-Smith antibody ? (y/n/ni/b)
# n
#
# The following part is about clinical data
# {'Acute cutaneous lupus': 'N',
#  'Acute pericarditis': 'N',
#  'Autoimmune hemolysis': 'N',
#  'Delirium': 'Y',
#  'Fever': 'Y',
#  'Joint involvement': 'N',
#  'Leukopenia': 'Y',
#  'Non-scarring alopecia': 'N',
#  'Oral ulcers': 'NI',
#  'Pleural or pericardial effusion': 'Y',
#  'Proteinuria >0.5g/24h': 'N',
#  'Psychosis': 'N',
#  'Renal biopsy Class II or V lupus nephritis': 'N',
#  'Renal biopsy Class III or IV lupus nephritis': 'N',
#  'Seizure': 'N',
#  'Subacute cutaneous OR discoid lupus': 'N',
#  'Thrombocytopenia': 'NI'}
# Proteinuria value: 401.0
#
# The following part is about immunology data
# {'Anti-cardiolipin antibodies OR Anti-β2GP1 antibodies OR  Lupus anticoagulant': 'Y',
#  'Anti-dsDNA antibody* OR Anti-Smith antibody': 'N',
#  'Low C3 AND low C4': 'N',
#  'Low C3 OR low C4 ': 'N'}
# Please confirm whether the result is correct or not(y/n):y
# The patient is diagnosed as SLE
# If you need more precise results, you need to complete the patient's data by doing the following tests
# Here are the missing data of the patient in the clinical domain
# Thrombocytopenia
# Oral ulcers
# Here are the missing data of the patient in the immunology domain
#
# Here is the main cause of the patient to be diagnosed as an SLE patient
# Seizure
# The score of the main cause accounts for 35.714285714285715 % of the total points
# 35.714285714285715 %
